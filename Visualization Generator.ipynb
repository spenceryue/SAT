# %%
# Returns list of BFS layers from given (full, unabridged) adjacency list <adj>

def bfs (adj, start=None, append_empty=True):
    # Precondition:
    assert adj
    
    # Track remaining unprocessed nodes
    remaining = {x for x in adj.keys ()}
    
    # Decide BFS starting root node
    if start in remaining:
        remaining.remove (start)
    else:
        start = remaining.pop ()
    
    # BFS layers and record of seen nodes
    layers = [{start}]
    seen = {start}
    
    while remaining:
        # Prepare to construct next_layer
        prev_layer = layers[-1]
        next_layer = set ()
        
        # Populate next_layer
        for node in prev_layer:
            next_layer |= adj[node]
        next_layer -= seen
        
        # Record next_layer
        remaining -= next_layer
        seen |= next_layer
        # Note: Append even if next_layer is empty.
        # An empty set will separate layers of
        # different connected components
        layers.append (next_layer)
        
        # Start new connected component
        if not next_layer and remaining:
            if not append_empty:
                layers.pop ()
            start = remaining.pop ()
            seen.add (start)
            layers.append ({start})
        
        # Remove final trailing empty set (applicable iff append_empty option set)
        elif not next_layer:
            layers.pop ()
            
    return layers

# %%
# Recursively forms nested BFS layers from each BFS layer

def recursive_bfs (adj, **kwargs):
    # Precondition:
    assert adj
    
    # Run BFS initially to get layers
    layers = bfs (adj, **kwargs)

    # Recursively decompose each BFS layer
    for i, layer in enumerate (layers):
        # Prepare layer-local adj
        # (i.e. restrict edges to nodes within this layer)
        local_adj = {node: adj[node] & layer for node in layer}
        
        # Done if there is one or fewer nodes
        if len (local_adj) <= 1:
            continue
        
        # Update layer with recursively decomposed result
        else:
            layers[i] = recursive_bfs (local_adj, **kwargs)

    return layers

# %%
# Convert RBFS layers into HTML representation

def render (rbfs_tree, input_base, depth=0):
    text = []
    
    # Record seen nodes just to double-check
    seen = set ()

    # Set div orientation and indent level
    indent = '  ' * (depth + 2)
    if depth % 2:
        orientation = 'horizontal'
    else:
        orientation = 'vertical'

    # Render each layer (recursively if needed)
    for i, layer in enumerate (rbfs_tree):
        
        # Connected component divider
        if not layer:
            text.append ('{}<div class="break {}"></div>'.format (indent, orientation))
        
        # Node
        elif isinstance (layer, set):
            index, = [x for x in layer]
            text.append ('{}<div id="node_{}" class="node {}">{}</div>'.format (indent, index, orientation, index))
            seen.update (layer)
            
        # Layer (must recurse deeper)
        else:
            rendered, _ = render (layer, input_base, depth=depth+1)
            text.append ('{}<div class="layer {}">\n{}\n{}</div>'.format (indent, orientation, rendered, indent))
            seen.update (_)
    
    # Join rendered layers
    text = '\n'.join (text)
    
    # For outermost level, wrap in container, apply stylesheet
    if depth == 0:
        template = '''\
<!DOCTYPE html>
<html>
<head>
  <title>BFS Decomposition: {}</title>
</head>
<body>
  <div class="container horizontal">
  <canvas></canvas>
{}
  </div>
  <link rel="stylesheet" type="text/css" href="../css/style.css">'
  <script type="module" src="../js/render.js"></script>
</body>
</html>'''
        text = template.format (input_base, text)
    
    return text, seen

# %%
# Generates html, json files for graph given in <input_file>

def process (input_file):
    
    from os.path import basename
    input_base = basename (input_file).split ('.')[0]
    
    #####################################################
    
    with open (input_file, 'r') as f:
        raw_lines = f.readlines ()
    
    #####################################################
    
    clauses = []

    for line in raw_lines:
        try:
            clause = [int (x) for x in line.split ()][:3]
            if len (clause) == 3:
                clauses.append (clause)
        except:
            pass
        
    #####################################################
    
    flattened = [x for clause in clauses for x in clause]
    
    #####################################################
    
    uniques = set (flattened)
    
    #####################################################
    
    from collections import defaultdict

    value2indices = defaultdict (list)

    for i,x in enumerate (flattened):
        value2indices[x].append (i)

    #####################################################
    
    from itertools import combinations

    adjacencies = defaultdict (set)

    for i, clause in enumerate (clauses):
        base = 3 * i
        for j, literal  in enumerate (clause):
            idx = base + j

            # A literal is adjacent to literals that are its complement...
            complement = value2indices[-literal]
            adjacencies[idx].update (complement)

            # ...and to the Literals in the same clause
            adjacencies[idx].update ({base + offset for offset in range (3)})
            adjacencies[idx].remove (idx)
    
    #####################################################
    
    abridged_adj = {k: {i for i in v if i > k} for k,v in adjacencies.items ()}
    
    #####################################################
    
    rbfs_layers = recursive_bfs (adjacencies)
    
    #####################################################
    
    html_file = 'html/{}.html'.format (input_base)
    
    #####################################################
    
    text, seen = render (rbfs_layers, input_base)

    with open (html_file, 'wt') as f:
        f.write (text)
        
    #####################################################
    
    edges_file = 'json/{}.json'.format (input_base)
    
    #####################################################
    
    import json
    with open (edges_file, 'wt') as f:
        json.dump ({node: sorted (adjacent) for node, adjacent in abridged_adj.items ()}, f, indent=2, sort_keys=True)

# %%
# Process all files in <data_dir>

from os import listdir, path

data_dir = 'uf20-91'

for input_file in listdir (data_dir):
    filepath = path.join (data_dir, input_file)
    print ('Processing {}'.format (filepath))
    process (filepath)
# Out:
# Processing uf20-91\uf20-01.cnf
# Processing uf20-91\uf20-010.cnf
# Processing uf20-91\uf20-0100.cnf
# Processing uf20-91\uf20-01000.cnf
# Processing uf20-91\uf20-0101.cnf
# Processing uf20-91\uf20-0102.cnf
# Processing uf20-91\uf20-0103.cnf
# Processing uf20-91\uf20-0104.cnf
# Processing uf20-91\uf20-0105.cnf
# Processing uf20-91\uf20-0106.cnf
# Processing uf20-91\uf20-0107.cnf
# Processing uf20-91\uf20-0108.cnf
# Processing uf20-91\uf20-0109.cnf
# Processing uf20-91\uf20-011.cnf
# Processing uf20-91\uf20-0110.cnf
# Processing uf20-91\uf20-0111.cnf
# Processing uf20-91\uf20-0112.cnf
# Processing uf20-91\uf20-0113.cnf
# Processing uf20-91\uf20-0114.cnf
# Processing uf20-91\uf20-0115.cnf
# Processing uf20-91\uf20-0116.cnf
# Processing uf20-91\uf20-0117.cnf
# Processing uf20-91\uf20-0118.cnf
# Processing uf20-91\uf20-0119.cnf
# Processing uf20-91\uf20-012.cnf
# Processing uf20-91\uf20-0120.cnf
# Processing uf20-91\uf20-0121.cnf
# Processing uf20-91\uf20-0122.cnf
# Processing uf20-91\uf20-0123.cnf
# Processing uf20-91\uf20-0124.cnf
# Processing uf20-91\uf20-0125.cnf
# Processing uf20-91\uf20-0126.cnf
# Processing uf20-91\uf20-0127.cnf
# Processing uf20-91\uf20-0128.cnf
# Processing uf20-91\uf20-0129.cnf
# Processing uf20-91\uf20-013.cnf
# Processing uf20-91\uf20-0130.cnf
# Processing uf20-91\uf20-0131.cnf
# Processing uf20-91\uf20-0132.cnf
# Processing uf20-91\uf20-0133.cnf
# Processing uf20-91\uf20-0134.cnf
# Processing uf20-91\uf20-0135.cnf
# Processing uf20-91\uf20-0136.cnf
# Processing uf20-91\uf20-0137.cnf
# Processing uf20-91\uf20-0138.cnf
# Processing uf20-91\uf20-0139.cnf
# Processing uf20-91\uf20-014.cnf
# Processing uf20-91\uf20-0140.cnf
# Processing uf20-91\uf20-0141.cnf
# Processing uf20-91\uf20-0142.cnf
# Processing uf20-91\uf20-0143.cnf
# Processing uf20-91\uf20-0144.cnf
# Processing uf20-91\uf20-0145.cnf
# Processing uf20-91\uf20-0146.cnf
# Processing uf20-91\uf20-0147.cnf
# Processing uf20-91\uf20-0148.cnf
# Processing uf20-91\uf20-0149.cnf
# Processing uf20-91\uf20-015.cnf
# Processing uf20-91\uf20-0150.cnf
# Processing uf20-91\uf20-0151.cnf
# Processing uf20-91\uf20-0152.cnf
# Processing uf20-91\uf20-0153.cnf
# Processing uf20-91\uf20-0154.cnf
# Processing uf20-91\uf20-0155.cnf
# Processing uf20-91\uf20-0156.cnf
# Processing uf20-91\uf20-0157.cnf
# Processing uf20-91\uf20-0158.cnf
# Processing uf20-91\uf20-0159.cnf
# Processing uf20-91\uf20-016.cnf
# Processing uf20-91\uf20-0160.cnf
# Processing uf20-91\uf20-0161.cnf
# Processing uf20-91\uf20-0162.cnf
# Processing uf20-91\uf20-0163.cnf
# Processing uf20-91\uf20-0164.cnf
# Processing uf20-91\uf20-0165.cnf
# Processing uf20-91\uf20-0166.cnf
# Processing uf20-91\uf20-0167.cnf
# Processing uf20-91\uf20-0168.cnf
# Processing uf20-91\uf20-0169.cnf
# Processing uf20-91\uf20-017.cnf
# Processing uf20-91\uf20-0170.cnf
# Processing uf20-91\uf20-0171.cnf
# Processing uf20-91\uf20-0172.cnf
# Processing uf20-91\uf20-0173.cnf
# Processing uf20-91\uf20-0174.cnf
# Processing uf20-91\uf20-0175.cnf
# Processing uf20-91\uf20-0176.cnf
# Processing uf20-91\uf20-0177.cnf
# Processing uf20-91\uf20-0178.cnf
# Processing uf20-91\uf20-0179.cnf
# Processing uf20-91\uf20-018.cnf
# Processing uf20-91\uf20-0180.cnf
# Processing uf20-91\uf20-0181.cnf
# Processing uf20-91\uf20-0182.cnf
# Processing uf20-91\uf20-0183.cnf
# Processing uf20-91\uf20-0184.cnf
# Processing uf20-91\uf20-0185.cnf
# Processing uf20-91\uf20-0186.cnf
# Processing uf20-91\uf20-0187.cnf
# Processing uf20-91\uf20-0188.cnf
# Processing uf20-91\uf20-0189.cnf
# Processing uf20-91\uf20-019.cnf
# Processing uf20-91\uf20-0190.cnf
# Processing uf20-91\uf20-0191.cnf
# Processing uf20-91\uf20-0192.cnf
# Processing uf20-91\uf20-0193.cnf
# Processing uf20-91\uf20-0194.cnf
# Processing uf20-91\uf20-0195.cnf
# Processing uf20-91\uf20-0196.cnf
# Processing uf20-91\uf20-0197.cnf
# Processing uf20-91\uf20-0198.cnf
# Processing uf20-91\uf20-0199.cnf
# Processing uf20-91\uf20-02.cnf
# Processing uf20-91\uf20-020.cnf
# Processing uf20-91\uf20-0200.cnf
# Processing uf20-91\uf20-0201.cnf
# Processing uf20-91\uf20-0202.cnf
# Processing uf20-91\uf20-0203.cnf
# Processing uf20-91\uf20-0204.cnf
# Processing uf20-91\uf20-0205.cnf
# Processing uf20-91\uf20-0206.cnf
# Processing uf20-91\uf20-0207.cnf
# Processing uf20-91\uf20-0208.cnf
# Processing uf20-91\uf20-0209.cnf
# Processing uf20-91\uf20-021.cnf
# Processing uf20-91\uf20-0210.cnf
# Processing uf20-91\uf20-0211.cnf
# Processing uf20-91\uf20-0212.cnf
# Processing uf20-91\uf20-0213.cnf
# Processing uf20-91\uf20-0214.cnf
# Processing uf20-91\uf20-0215.cnf
# Processing uf20-91\uf20-0216.cnf
# Processing uf20-91\uf20-0217.cnf
# Processing uf20-91\uf20-0218.cnf
# Processing uf20-91\uf20-0219.cnf
# Processing uf20-91\uf20-022.cnf
# Processing uf20-91\uf20-0220.cnf
# Processing uf20-91\uf20-0221.cnf
# Processing uf20-91\uf20-0222.cnf
# Processing uf20-91\uf20-0223.cnf
# Processing uf20-91\uf20-0224.cnf
# Processing uf20-91\uf20-0225.cnf
# Processing uf20-91\uf20-0226.cnf
# Processing uf20-91\uf20-0227.cnf
# Processing uf20-91\uf20-0228.cnf
# Processing uf20-91\uf20-0229.cnf
# Processing uf20-91\uf20-023.cnf
# Processing uf20-91\uf20-0230.cnf
# Processing uf20-91\uf20-0231.cnf
# Processing uf20-91\uf20-0232.cnf
# Processing uf20-91\uf20-0233.cnf
# Processing uf20-91\uf20-0234.cnf
# Processing uf20-91\uf20-0235.cnf
# Processing uf20-91\uf20-0236.cnf
# Processing uf20-91\uf20-0237.cnf
# Processing uf20-91\uf20-0238.cnf
# Processing uf20-91\uf20-0239.cnf
# Processing uf20-91\uf20-024.cnf
# Processing uf20-91\uf20-0240.cnf
# Processing uf20-91\uf20-0241.cnf
# Processing uf20-91\uf20-0242.cnf
# Processing uf20-91\uf20-0243.cnf
# Processing uf20-91\uf20-0244.cnf
# Processing uf20-91\uf20-0245.cnf
# Processing uf20-91\uf20-0246.cnf
# Processing uf20-91\uf20-0247.cnf
# Processing uf20-91\uf20-0248.cnf
# Processing uf20-91\uf20-0249.cnf
# Processing uf20-91\uf20-025.cnf
# Processing uf20-91\uf20-0250.cnf
# Processing uf20-91\uf20-0251.cnf
# Processing uf20-91\uf20-0252.cnf
# Processing uf20-91\uf20-0253.cnf
# Processing uf20-91\uf20-0254.cnf
# Processing uf20-91\uf20-0255.cnf
# Processing uf20-91\uf20-0256.cnf
# Processing uf20-91\uf20-0257.cnf
# Processing uf20-91\uf20-0258.cnf
# Processing uf20-91\uf20-0259.cnf
# Processing uf20-91\uf20-026.cnf
# Processing uf20-91\uf20-0260.cnf
# Processing uf20-91\uf20-0261.cnf
# Processing uf20-91\uf20-0262.cnf
# Processing uf20-91\uf20-0263.cnf
# Processing uf20-91\uf20-0264.cnf
# Processing uf20-91\uf20-0265.cnf
# Processing uf20-91\uf20-0266.cnf
# Processing uf20-91\uf20-0267.cnf
# Processing uf20-91\uf20-0268.cnf
# Processing uf20-91\uf20-0269.cnf
# Processing uf20-91\uf20-027.cnf
# Processing uf20-91\uf20-0270.cnf
# Processing uf20-91\uf20-0271.cnf
# Processing uf20-91\uf20-0272.cnf
# Processing uf20-91\uf20-0273.cnf
# Processing uf20-91\uf20-0274.cnf
# Processing uf20-91\uf20-0275.cnf
# Processing uf20-91\uf20-0276.cnf
# Processing uf20-91\uf20-0277.cnf
# Processing uf20-91\uf20-0278.cnf
# Processing uf20-91\uf20-0279.cnf
# Processing uf20-91\uf20-028.cnf
# Processing uf20-91\uf20-0280.cnf
# Processing uf20-91\uf20-0281.cnf
# Processing uf20-91\uf20-0282.cnf
# Processing uf20-91\uf20-0283.cnf
# Processing uf20-91\uf20-0284.cnf
# Processing uf20-91\uf20-0285.cnf
# Processing uf20-91\uf20-0286.cnf
# Processing uf20-91\uf20-0287.cnf
# Processing uf20-91\uf20-0288.cnf
# Processing uf20-91\uf20-0289.cnf
# Processing uf20-91\uf20-029.cnf
# Processing uf20-91\uf20-0290.cnf
# Processing uf20-91\uf20-0291.cnf
# Processing uf20-91\uf20-0292.cnf
# Processing uf20-91\uf20-0293.cnf
# Processing uf20-91\uf20-0294.cnf
# Processing uf20-91\uf20-0295.cnf
# Processing uf20-91\uf20-0296.cnf
# Processing uf20-91\uf20-0297.cnf
# Processing uf20-91\uf20-0298.cnf
# Processing uf20-91\uf20-0299.cnf
# Processing uf20-91\uf20-03.cnf
# Processing uf20-91\uf20-030.cnf
# Processing uf20-91\uf20-0300.cnf
# Processing uf20-91\uf20-0301.cnf
# Processing uf20-91\uf20-0302.cnf
# Processing uf20-91\uf20-0303.cnf
# Processing uf20-91\uf20-0304.cnf
# Processing uf20-91\uf20-0305.cnf
# Processing uf20-91\uf20-0306.cnf
# Processing uf20-91\uf20-0307.cnf
# Processing uf20-91\uf20-0308.cnf
# Processing uf20-91\uf20-0309.cnf
# Processing uf20-91\uf20-031.cnf
# Processing uf20-91\uf20-0310.cnf
# Processing uf20-91\uf20-0311.cnf
# Processing uf20-91\uf20-0312.cnf
# Processing uf20-91\uf20-0313.cnf
# Processing uf20-91\uf20-0314.cnf
# Processing uf20-91\uf20-0315.cnf
# Processing uf20-91\uf20-0316.cnf
# Processing uf20-91\uf20-0317.cnf
# Processing uf20-91\uf20-0318.cnf
# Processing uf20-91\uf20-0319.cnf
# Processing uf20-91\uf20-032.cnf
# Processing uf20-91\uf20-0320.cnf
# Processing uf20-91\uf20-0321.cnf
# Processing uf20-91\uf20-0322.cnf
# Processing uf20-91\uf20-0323.cnf
# Processing uf20-91\uf20-0324.cnf
# Processing uf20-91\uf20-0325.cnf
# Processing uf20-91\uf20-0326.cnf
# Processing uf20-91\uf20-0327.cnf
# Processing uf20-91\uf20-0328.cnf
# Processing uf20-91\uf20-0329.cnf
# Processing uf20-91\uf20-033.cnf
# Processing uf20-91\uf20-0330.cnf
# Processing uf20-91\uf20-0331.cnf
# Processing uf20-91\uf20-0332.cnf
# Processing uf20-91\uf20-0333.cnf
# Processing uf20-91\uf20-0334.cnf
# Processing uf20-91\uf20-0335.cnf
# Processing uf20-91\uf20-0336.cnf
# Processing uf20-91\uf20-0337.cnf
# Processing uf20-91\uf20-0338.cnf
# Processing uf20-91\uf20-0339.cnf
# Processing uf20-91\uf20-034.cnf
# Processing uf20-91\uf20-0340.cnf
# Processing uf20-91\uf20-0341.cnf
# Processing uf20-91\uf20-0342.cnf
# Processing uf20-91\uf20-0343.cnf
# Processing uf20-91\uf20-0344.cnf
# Processing uf20-91\uf20-0345.cnf
# Processing uf20-91\uf20-0346.cnf
# Processing uf20-91\uf20-0347.cnf
# Processing uf20-91\uf20-0348.cnf
# Processing uf20-91\uf20-0349.cnf
# Processing uf20-91\uf20-035.cnf
# Processing uf20-91\uf20-0350.cnf
# Processing uf20-91\uf20-0351.cnf
# Processing uf20-91\uf20-0352.cnf
# Processing uf20-91\uf20-0353.cnf
# Processing uf20-91\uf20-0354.cnf
# Processing uf20-91\uf20-0355.cnf
# Processing uf20-91\uf20-0356.cnf
# Processing uf20-91\uf20-0357.cnf
# Processing uf20-91\uf20-0358.cnf
# Processing uf20-91\uf20-0359.cnf
# Processing uf20-91\uf20-036.cnf
# Processing uf20-91\uf20-0360.cnf
# Processing uf20-91\uf20-0361.cnf
# Processing uf20-91\uf20-0362.cnf
# Processing uf20-91\uf20-0363.cnf
# Processing uf20-91\uf20-0364.cnf
# Processing uf20-91\uf20-0365.cnf
# Processing uf20-91\uf20-0366.cnf
# Processing uf20-91\uf20-0367.cnf
# Processing uf20-91\uf20-0368.cnf
# Processing uf20-91\uf20-0369.cnf
# Processing uf20-91\uf20-037.cnf
# Processing uf20-91\uf20-0370.cnf
# Processing uf20-91\uf20-0371.cnf
# Processing uf20-91\uf20-0372.cnf
# Processing uf20-91\uf20-0373.cnf
# Processing uf20-91\uf20-0374.cnf
# Processing uf20-91\uf20-0375.cnf
# Processing uf20-91\uf20-0376.cnf
# Processing uf20-91\uf20-0377.cnf
# Processing uf20-91\uf20-0378.cnf
# Processing uf20-91\uf20-0379.cnf
# Processing uf20-91\uf20-038.cnf
# Processing uf20-91\uf20-0380.cnf
# Processing uf20-91\uf20-0381.cnf
# Processing uf20-91\uf20-0382.cnf
# Processing uf20-91\uf20-0383.cnf
# Processing uf20-91\uf20-0384.cnf
# Processing uf20-91\uf20-0385.cnf
# Processing uf20-91\uf20-0386.cnf
# Processing uf20-91\uf20-0387.cnf
# Processing uf20-91\uf20-0388.cnf
# Processing uf20-91\uf20-0389.cnf
# Processing uf20-91\uf20-039.cnf
# Processing uf20-91\uf20-0390.cnf
# Processing uf20-91\uf20-0391.cnf
# Processing uf20-91\uf20-0392.cnf
# Processing uf20-91\uf20-0393.cnf
# Processing uf20-91\uf20-0394.cnf
# Processing uf20-91\uf20-0395.cnf
# Processing uf20-91\uf20-0396.cnf
# Processing uf20-91\uf20-0397.cnf
# Processing uf20-91\uf20-0398.cnf
# Processing uf20-91\uf20-0399.cnf
# Processing uf20-91\uf20-04.cnf
# Processing uf20-91\uf20-040.cnf
# Processing uf20-91\uf20-0400.cnf
# Processing uf20-91\uf20-0401.cnf
# Processing uf20-91\uf20-0402.cnf
# Processing uf20-91\uf20-0403.cnf
# Processing uf20-91\uf20-0404.cnf
# Processing uf20-91\uf20-0405.cnf
# Processing uf20-91\uf20-0406.cnf
# Processing uf20-91\uf20-0407.cnf
# Processing uf20-91\uf20-0408.cnf
# Processing uf20-91\uf20-0409.cnf
# Processing uf20-91\uf20-041.cnf
# Processing uf20-91\uf20-0410.cnf
# Processing uf20-91\uf20-0411.cnf
# Processing uf20-91\uf20-0412.cnf
# Processing uf20-91\uf20-0413.cnf
# Processing uf20-91\uf20-0414.cnf
# Processing uf20-91\uf20-0415.cnf
# Processing uf20-91\uf20-0416.cnf
# Processing uf20-91\uf20-0417.cnf
# Processing uf20-91\uf20-0418.cnf
# Processing uf20-91\uf20-0419.cnf
# Processing uf20-91\uf20-042.cnf
# Processing uf20-91\uf20-0420.cnf
# Processing uf20-91\uf20-0421.cnf
# Processing uf20-91\uf20-0422.cnf
# Processing uf20-91\uf20-0423.cnf
# Processing uf20-91\uf20-0424.cnf
# Processing uf20-91\uf20-0425.cnf
# Processing uf20-91\uf20-0426.cnf
# Processing uf20-91\uf20-0427.cnf
# Processing uf20-91\uf20-0428.cnf
# Processing uf20-91\uf20-0429.cnf
# Processing uf20-91\uf20-043.cnf
# Processing uf20-91\uf20-0430.cnf
# Processing uf20-91\uf20-0431.cnf
# Processing uf20-91\uf20-0432.cnf
# Processing uf20-91\uf20-0433.cnf
# Processing uf20-91\uf20-0434.cnf
# Processing uf20-91\uf20-0435.cnf
# Processing uf20-91\uf20-0436.cnf
# Processing uf20-91\uf20-0437.cnf
# Processing uf20-91\uf20-0438.cnf
# Processing uf20-91\uf20-0439.cnf
# Processing uf20-91\uf20-044.cnf
# Processing uf20-91\uf20-0440.cnf
# Processing uf20-91\uf20-0441.cnf
# Processing uf20-91\uf20-0442.cnf
# Processing uf20-91\uf20-0443.cnf
# Processing uf20-91\uf20-0444.cnf
# Processing uf20-91\uf20-0445.cnf
# Processing uf20-91\uf20-0446.cnf
# Processing uf20-91\uf20-0447.cnf
# Processing uf20-91\uf20-0448.cnf
# Processing uf20-91\uf20-0449.cnf
# Processing uf20-91\uf20-045.cnf
# Processing uf20-91\uf20-0450.cnf
# Processing uf20-91\uf20-0451.cnf
# Processing uf20-91\uf20-0452.cnf
# Processing uf20-91\uf20-0453.cnf
# Processing uf20-91\uf20-0454.cnf
# Processing uf20-91\uf20-0455.cnf
# Processing uf20-91\uf20-0456.cnf
# Processing uf20-91\uf20-0457.cnf
# Processing uf20-91\uf20-0458.cnf
# Processing uf20-91\uf20-0459.cnf
# Processing uf20-91\uf20-046.cnf
# Processing uf20-91\uf20-0460.cnf
# Processing uf20-91\uf20-0461.cnf
# Processing uf20-91\uf20-0462.cnf
# Processing uf20-91\uf20-0463.cnf
# Processing uf20-91\uf20-0464.cnf
# Processing uf20-91\uf20-0465.cnf
# Processing uf20-91\uf20-0466.cnf
# Processing uf20-91\uf20-0467.cnf
# Processing uf20-91\uf20-0468.cnf
# Processing uf20-91\uf20-0469.cnf
# Processing uf20-91\uf20-047.cnf
# Processing uf20-91\uf20-0470.cnf
# Processing uf20-91\uf20-0471.cnf
# Processing uf20-91\uf20-0472.cnf
# Processing uf20-91\uf20-0473.cnf
# Processing uf20-91\uf20-0474.cnf
# Processing uf20-91\uf20-0475.cnf
# Processing uf20-91\uf20-0476.cnf
# Processing uf20-91\uf20-0477.cnf
# Processing uf20-91\uf20-0478.cnf
# Processing uf20-91\uf20-0479.cnf
# Processing uf20-91\uf20-048.cnf
# Processing uf20-91\uf20-0480.cnf
# Processing uf20-91\uf20-0481.cnf
# Processing uf20-91\uf20-0482.cnf
# Processing uf20-91\uf20-0483.cnf
# Processing uf20-91\uf20-0484.cnf
# Processing uf20-91\uf20-0485.cnf
# Processing uf20-91\uf20-0486.cnf
# Processing uf20-91\uf20-0487.cnf
# Processing uf20-91\uf20-0488.cnf
# Processing uf20-91\uf20-0489.cnf
# Processing uf20-91\uf20-049.cnf
# Processing uf20-91\uf20-0490.cnf
# Processing uf20-91\uf20-0491.cnf
# Processing uf20-91\uf20-0492.cnf
# Processing uf20-91\uf20-0493.cnf
# Processing uf20-91\uf20-0494.cnf
# Processing uf20-91\uf20-0495.cnf
# Processing uf20-91\uf20-0496.cnf
# Processing uf20-91\uf20-0497.cnf
# Processing uf20-91\uf20-0498.cnf
# Processing uf20-91\uf20-0499.cnf
# Processing uf20-91\uf20-05.cnf
# Processing uf20-91\uf20-050.cnf
# Processing uf20-91\uf20-0500.cnf
# Processing uf20-91\uf20-0501.cnf
# Processing uf20-91\uf20-0502.cnf
# Processing uf20-91\uf20-0503.cnf
# Processing uf20-91\uf20-0504.cnf
# Processing uf20-91\uf20-0505.cnf
# Processing uf20-91\uf20-0506.cnf
# Processing uf20-91\uf20-0507.cnf
# Processing uf20-91\uf20-0508.cnf
# Processing uf20-91\uf20-0509.cnf
# Processing uf20-91\uf20-051.cnf
# Processing uf20-91\uf20-0510.cnf
# Processing uf20-91\uf20-0511.cnf
# Processing uf20-91\uf20-0512.cnf
# Processing uf20-91\uf20-0513.cnf
# Processing uf20-91\uf20-0514.cnf
# Processing uf20-91\uf20-0515.cnf
# Processing uf20-91\uf20-0516.cnf
# Processing uf20-91\uf20-0517.cnf
# Processing uf20-91\uf20-0518.cnf
# Processing uf20-91\uf20-0519.cnf
# Processing uf20-91\uf20-052.cnf
# Processing uf20-91\uf20-0520.cnf
# Processing uf20-91\uf20-0521.cnf
# Processing uf20-91\uf20-0522.cnf
# Processing uf20-91\uf20-0523.cnf
# Processing uf20-91\uf20-0524.cnf
# Processing uf20-91\uf20-0525.cnf
# Processing uf20-91\uf20-0526.cnf
# Processing uf20-91\uf20-0527.cnf
# Processing uf20-91\uf20-0528.cnf
# Processing uf20-91\uf20-0529.cnf
# Processing uf20-91\uf20-053.cnf
# Processing uf20-91\uf20-0530.cnf
# Processing uf20-91\uf20-0531.cnf
# Processing uf20-91\uf20-0532.cnf
# Processing uf20-91\uf20-0533.cnf
# Processing uf20-91\uf20-0534.cnf
# Processing uf20-91\uf20-0535.cnf
# Processing uf20-91\uf20-0536.cnf
# Processing uf20-91\uf20-0537.cnf
# Processing uf20-91\uf20-0538.cnf
# Processing uf20-91\uf20-0539.cnf
# Processing uf20-91\uf20-054.cnf
# Processing uf20-91\uf20-0540.cnf
# Processing uf20-91\uf20-0541.cnf
# Processing uf20-91\uf20-0542.cnf
# Processing uf20-91\uf20-0543.cnf
# Processing uf20-91\uf20-0544.cnf
# Processing uf20-91\uf20-0545.cnf
# Processing uf20-91\uf20-0546.cnf
# Processing uf20-91\uf20-0547.cnf
# Processing uf20-91\uf20-0548.cnf
# Processing uf20-91\uf20-0549.cnf
# Processing uf20-91\uf20-055.cnf
# Processing uf20-91\uf20-0550.cnf
# Processing uf20-91\uf20-0551.cnf
# Processing uf20-91\uf20-0552.cnf
# Processing uf20-91\uf20-0553.cnf
# Processing uf20-91\uf20-0554.cnf
# Processing uf20-91\uf20-0555.cnf
# Processing uf20-91\uf20-0556.cnf
# Processing uf20-91\uf20-0557.cnf
# Processing uf20-91\uf20-0558.cnf
# Processing uf20-91\uf20-0559.cnf
# Processing uf20-91\uf20-056.cnf
# Processing uf20-91\uf20-0560.cnf
# Processing uf20-91\uf20-0561.cnf
# Processing uf20-91\uf20-0562.cnf
# Processing uf20-91\uf20-0563.cnf
# Processing uf20-91\uf20-0564.cnf
# Processing uf20-91\uf20-0565.cnf
# Processing uf20-91\uf20-0566.cnf
# Processing uf20-91\uf20-0567.cnf
# Processing uf20-91\uf20-0568.cnf
# Processing uf20-91\uf20-0569.cnf
# Processing uf20-91\uf20-057.cnf
# Processing uf20-91\uf20-0570.cnf
# Processing uf20-91\uf20-0571.cnf
# Processing uf20-91\uf20-0572.cnf
# Processing uf20-91\uf20-0573.cnf
# Processing uf20-91\uf20-0574.cnf
# Processing uf20-91\uf20-0575.cnf
# Processing uf20-91\uf20-0576.cnf
# Processing uf20-91\uf20-0577.cnf
# Processing uf20-91\uf20-0578.cnf
# Processing uf20-91\uf20-0579.cnf
# Processing uf20-91\uf20-058.cnf
# Processing uf20-91\uf20-0580.cnf
# Processing uf20-91\uf20-0581.cnf
# Processing uf20-91\uf20-0582.cnf
# Processing uf20-91\uf20-0583.cnf
# Processing uf20-91\uf20-0584.cnf
# Processing uf20-91\uf20-0585.cnf
# Processing uf20-91\uf20-0586.cnf
# Processing uf20-91\uf20-0587.cnf
# Processing uf20-91\uf20-0588.cnf
# Processing uf20-91\uf20-0589.cnf
# Processing uf20-91\uf20-059.cnf
# Processing uf20-91\uf20-0590.cnf
# Processing uf20-91\uf20-0591.cnf
# Processing uf20-91\uf20-0592.cnf
# Processing uf20-91\uf20-0593.cnf
# Processing uf20-91\uf20-0594.cnf
# Processing uf20-91\uf20-0595.cnf
# Processing uf20-91\uf20-0596.cnf
# Processing uf20-91\uf20-0597.cnf
# Processing uf20-91\uf20-0598.cnf
# Processing uf20-91\uf20-0599.cnf
# Processing uf20-91\uf20-06.cnf
# Processing uf20-91\uf20-060.cnf
# Processing uf20-91\uf20-0600.cnf
# Processing uf20-91\uf20-0601.cnf
# Processing uf20-91\uf20-0602.cnf
# Processing uf20-91\uf20-0603.cnf
# Processing uf20-91\uf20-0604.cnf
# Processing uf20-91\uf20-0605.cnf
# Processing uf20-91\uf20-0606.cnf
# Processing uf20-91\uf20-0607.cnf
# Processing uf20-91\uf20-0608.cnf
# Processing uf20-91\uf20-0609.cnf
# Processing uf20-91\uf20-061.cnf
# Processing uf20-91\uf20-0610.cnf
# Processing uf20-91\uf20-0611.cnf
# Processing uf20-91\uf20-0612.cnf
# Processing uf20-91\uf20-0613.cnf
# Processing uf20-91\uf20-0614.cnf
# Processing uf20-91\uf20-0615.cnf
# Processing uf20-91\uf20-0616.cnf
# Processing uf20-91\uf20-0617.cnf
# Processing uf20-91\uf20-0618.cnf
# Processing uf20-91\uf20-0619.cnf
# Processing uf20-91\uf20-062.cnf
# Processing uf20-91\uf20-0620.cnf
# Processing uf20-91\uf20-0621.cnf
# Processing uf20-91\uf20-0622.cnf
# Processing uf20-91\uf20-0623.cnf
# Processing uf20-91\uf20-0624.cnf
# Processing uf20-91\uf20-0625.cnf
# Processing uf20-91\uf20-0626.cnf
# Processing uf20-91\uf20-0627.cnf
# Processing uf20-91\uf20-0628.cnf
# Processing uf20-91\uf20-0629.cnf
# Processing uf20-91\uf20-063.cnf
# Processing uf20-91\uf20-0630.cnf
# Processing uf20-91\uf20-0631.cnf
# Processing uf20-91\uf20-0632.cnf
# Processing uf20-91\uf20-0633.cnf
# Processing uf20-91\uf20-0634.cnf
# Processing uf20-91\uf20-0635.cnf
# Processing uf20-91\uf20-0636.cnf
# Processing uf20-91\uf20-0637.cnf
# Processing uf20-91\uf20-0638.cnf
# Processing uf20-91\uf20-0639.cnf
# Processing uf20-91\uf20-064.cnf
# Processing uf20-91\uf20-0640.cnf
# Processing uf20-91\uf20-0641.cnf
# Processing uf20-91\uf20-0642.cnf
# Processing uf20-91\uf20-0643.cnf
# Processing uf20-91\uf20-0644.cnf
# Processing uf20-91\uf20-0645.cnf
# Processing uf20-91\uf20-0646.cnf
# Processing uf20-91\uf20-0647.cnf
# Processing uf20-91\uf20-0648.cnf
# Processing uf20-91\uf20-0649.cnf
# Processing uf20-91\uf20-065.cnf
# Processing uf20-91\uf20-0650.cnf
# Processing uf20-91\uf20-0651.cnf
# Processing uf20-91\uf20-0652.cnf
# Processing uf20-91\uf20-0653.cnf
# Processing uf20-91\uf20-0654.cnf
# Processing uf20-91\uf20-0655.cnf
# Processing uf20-91\uf20-0656.cnf
# Processing uf20-91\uf20-0657.cnf
# Processing uf20-91\uf20-0658.cnf
# Processing uf20-91\uf20-0659.cnf
# Processing uf20-91\uf20-066.cnf
# Processing uf20-91\uf20-0660.cnf
# Processing uf20-91\uf20-0661.cnf
# Processing uf20-91\uf20-0662.cnf
# Processing uf20-91\uf20-0663.cnf
# Processing uf20-91\uf20-0664.cnf
# Processing uf20-91\uf20-0665.cnf
# Processing uf20-91\uf20-0666.cnf
# Processing uf20-91\uf20-0667.cnf
# Processing uf20-91\uf20-0668.cnf
# Processing uf20-91\uf20-0669.cnf
# Processing uf20-91\uf20-067.cnf
# Processing uf20-91\uf20-0670.cnf
# Processing uf20-91\uf20-0671.cnf
# Processing uf20-91\uf20-0672.cnf
# Processing uf20-91\uf20-0673.cnf
# Processing uf20-91\uf20-0674.cnf
# Processing uf20-91\uf20-0675.cnf
# Processing uf20-91\uf20-0676.cnf
# Processing uf20-91\uf20-0677.cnf
# Processing uf20-91\uf20-0678.cnf
# Processing uf20-91\uf20-0679.cnf
# Processing uf20-91\uf20-068.cnf
# Processing uf20-91\uf20-0680.cnf
# Processing uf20-91\uf20-0681.cnf
# Processing uf20-91\uf20-0682.cnf
# Processing uf20-91\uf20-0683.cnf
# Processing uf20-91\uf20-0684.cnf
# Processing uf20-91\uf20-0685.cnf
# Processing uf20-91\uf20-0686.cnf
# Processing uf20-91\uf20-0687.cnf
# Processing uf20-91\uf20-0688.cnf
# Processing uf20-91\uf20-0689.cnf
# Processing uf20-91\uf20-069.cnf
# Processing uf20-91\uf20-0690.cnf
# Processing uf20-91\uf20-0691.cnf
# Processing uf20-91\uf20-0692.cnf
# Processing uf20-91\uf20-0693.cnf
# Processing uf20-91\uf20-0694.cnf
# Processing uf20-91\uf20-0695.cnf
# Processing uf20-91\uf20-0696.cnf
# Processing uf20-91\uf20-0697.cnf
# Processing uf20-91\uf20-0698.cnf
# Processing uf20-91\uf20-0699.cnf
# Processing uf20-91\uf20-07.cnf
# Processing uf20-91\uf20-070.cnf
# Processing uf20-91\uf20-0700.cnf
# Processing uf20-91\uf20-0701.cnf
# Processing uf20-91\uf20-0702.cnf
# Processing uf20-91\uf20-0703.cnf
# Processing uf20-91\uf20-0704.cnf
# Processing uf20-91\uf20-0705.cnf
# Processing uf20-91\uf20-0706.cnf
# Processing uf20-91\uf20-0707.cnf
# Processing uf20-91\uf20-0708.cnf
# Processing uf20-91\uf20-0709.cnf
# Processing uf20-91\uf20-071.cnf
# Processing uf20-91\uf20-0710.cnf
# Processing uf20-91\uf20-0711.cnf
# Processing uf20-91\uf20-0712.cnf
# Processing uf20-91\uf20-0713.cnf
# Processing uf20-91\uf20-0714.cnf
# Processing uf20-91\uf20-0715.cnf
# Processing uf20-91\uf20-0716.cnf
# Processing uf20-91\uf20-0717.cnf
# Processing uf20-91\uf20-0718.cnf
# Processing uf20-91\uf20-0719.cnf
# Processing uf20-91\uf20-072.cnf
# Processing uf20-91\uf20-0720.cnf
# Processing uf20-91\uf20-0721.cnf
# Processing uf20-91\uf20-0722.cnf
# Processing uf20-91\uf20-0723.cnf
# Processing uf20-91\uf20-0724.cnf
# Processing uf20-91\uf20-0725.cnf
# Processing uf20-91\uf20-0726.cnf
# Processing uf20-91\uf20-0727.cnf
# Processing uf20-91\uf20-0728.cnf
# Processing uf20-91\uf20-0729.cnf
# Processing uf20-91\uf20-073.cnf
# Processing uf20-91\uf20-0730.cnf
# Processing uf20-91\uf20-0731.cnf
# Processing uf20-91\uf20-0732.cnf
# Processing uf20-91\uf20-0733.cnf
# Processing uf20-91\uf20-0734.cnf
# Processing uf20-91\uf20-0735.cnf
# Processing uf20-91\uf20-0736.cnf
# Processing uf20-91\uf20-0737.cnf
# Processing uf20-91\uf20-0738.cnf
# Processing uf20-91\uf20-0739.cnf
# Processing uf20-91\uf20-074.cnf
# Processing uf20-91\uf20-0740.cnf
# Processing uf20-91\uf20-0741.cnf
# Processing uf20-91\uf20-0742.cnf
# Processing uf20-91\uf20-0743.cnf
# Processing uf20-91\uf20-0744.cnf
# Processing uf20-91\uf20-0745.cnf
# Processing uf20-91\uf20-0746.cnf
# Processing uf20-91\uf20-0747.cnf
# Processing uf20-91\uf20-0748.cnf
# Processing uf20-91\uf20-0749.cnf
# Processing uf20-91\uf20-075.cnf
# Processing uf20-91\uf20-0750.cnf
# Processing uf20-91\uf20-0751.cnf
# Processing uf20-91\uf20-0752.cnf
# Processing uf20-91\uf20-0753.cnf
# Processing uf20-91\uf20-0754.cnf
# Processing uf20-91\uf20-0755.cnf
# Processing uf20-91\uf20-0756.cnf
# Processing uf20-91\uf20-0757.cnf
# Processing uf20-91\uf20-0758.cnf
# Processing uf20-91\uf20-0759.cnf
# Processing uf20-91\uf20-076.cnf
# Processing uf20-91\uf20-0760.cnf
# Processing uf20-91\uf20-0761.cnf
# Processing uf20-91\uf20-0762.cnf
# Processing uf20-91\uf20-0763.cnf
# Processing uf20-91\uf20-0764.cnf
# Processing uf20-91\uf20-0765.cnf
# Processing uf20-91\uf20-0766.cnf
# Processing uf20-91\uf20-0767.cnf
# Processing uf20-91\uf20-0768.cnf
# Processing uf20-91\uf20-0769.cnf
# Processing uf20-91\uf20-077.cnf
# Processing uf20-91\uf20-0770.cnf
# Processing uf20-91\uf20-0771.cnf
# Processing uf20-91\uf20-0772.cnf
# Processing uf20-91\uf20-0773.cnf
# Processing uf20-91\uf20-0774.cnf
# Processing uf20-91\uf20-0775.cnf
# Processing uf20-91\uf20-0776.cnf
# Processing uf20-91\uf20-0777.cnf
# Processing uf20-91\uf20-0778.cnf
# Processing uf20-91\uf20-0779.cnf
# Processing uf20-91\uf20-078.cnf
# Processing uf20-91\uf20-0780.cnf
# Processing uf20-91\uf20-0781.cnf
# Processing uf20-91\uf20-0782.cnf
# Processing uf20-91\uf20-0783.cnf
# Processing uf20-91\uf20-0784.cnf
# Processing uf20-91\uf20-0785.cnf
# Processing uf20-91\uf20-0786.cnf
# Processing uf20-91\uf20-0787.cnf
# Processing uf20-91\uf20-0788.cnf
# Processing uf20-91\uf20-0789.cnf
# Processing uf20-91\uf20-079.cnf
# Processing uf20-91\uf20-0790.cnf
# Processing uf20-91\uf20-0791.cnf
# Processing uf20-91\uf20-0792.cnf
# Processing uf20-91\uf20-0793.cnf
# Processing uf20-91\uf20-0794.cnf
# Processing uf20-91\uf20-0795.cnf
# Processing uf20-91\uf20-0796.cnf
# Processing uf20-91\uf20-0797.cnf
# Processing uf20-91\uf20-0798.cnf
# Processing uf20-91\uf20-0799.cnf
# Processing uf20-91\uf20-08.cnf
# Processing uf20-91\uf20-080.cnf
# Processing uf20-91\uf20-0800.cnf
# Processing uf20-91\uf20-0801.cnf
# Processing uf20-91\uf20-0802.cnf
# Processing uf20-91\uf20-0803.cnf
# Processing uf20-91\uf20-0804.cnf
# Processing uf20-91\uf20-0805.cnf
# Processing uf20-91\uf20-0806.cnf
# Processing uf20-91\uf20-0807.cnf
# Processing uf20-91\uf20-0808.cnf
# Processing uf20-91\uf20-0809.cnf
# Processing uf20-91\uf20-081.cnf
# Processing uf20-91\uf20-0810.cnf
# Processing uf20-91\uf20-0811.cnf
# Processing uf20-91\uf20-0812.cnf
# Processing uf20-91\uf20-0813.cnf
# Processing uf20-91\uf20-0814.cnf
# Processing uf20-91\uf20-0815.cnf
# Processing uf20-91\uf20-0816.cnf
# Processing uf20-91\uf20-0817.cnf
# Processing uf20-91\uf20-0818.cnf
# Processing uf20-91\uf20-0819.cnf
# Processing uf20-91\uf20-082.cnf
# Processing uf20-91\uf20-0820.cnf
# Processing uf20-91\uf20-0821.cnf
# Processing uf20-91\uf20-0822.cnf
# Processing uf20-91\uf20-0823.cnf
# Processing uf20-91\uf20-0824.cnf
# Processing uf20-91\uf20-0825.cnf
# Processing uf20-91\uf20-0826.cnf
# Processing uf20-91\uf20-0827.cnf
# Processing uf20-91\uf20-0828.cnf
# Processing uf20-91\uf20-0829.cnf
# Processing uf20-91\uf20-083.cnf
# Processing uf20-91\uf20-0830.cnf
# Processing uf20-91\uf20-0831.cnf
# Processing uf20-91\uf20-0832.cnf
# Processing uf20-91\uf20-0833.cnf
# Processing uf20-91\uf20-0834.cnf
# Processing uf20-91\uf20-0835.cnf
# Processing uf20-91\uf20-0836.cnf
# Processing uf20-91\uf20-0837.cnf
# Processing uf20-91\uf20-0838.cnf
# Processing uf20-91\uf20-0839.cnf
# Processing uf20-91\uf20-084.cnf
# Processing uf20-91\uf20-0840.cnf
# Processing uf20-91\uf20-0841.cnf
# Processing uf20-91\uf20-0842.cnf
# Processing uf20-91\uf20-0843.cnf
# Processing uf20-91\uf20-0844.cnf
# Processing uf20-91\uf20-0845.cnf
# Processing uf20-91\uf20-0846.cnf
# Processing uf20-91\uf20-0847.cnf
# Processing uf20-91\uf20-0848.cnf
# Processing uf20-91\uf20-0849.cnf
# Processing uf20-91\uf20-085.cnf
# Processing uf20-91\uf20-0850.cnf
# Processing uf20-91\uf20-0851.cnf
# Processing uf20-91\uf20-0852.cnf
# Processing uf20-91\uf20-0853.cnf
# Processing uf20-91\uf20-0854.cnf
# Processing uf20-91\uf20-0855.cnf
# Processing uf20-91\uf20-0856.cnf
# Processing uf20-91\uf20-0857.cnf
# Processing uf20-91\uf20-0858.cnf
# Processing uf20-91\uf20-0859.cnf
# Processing uf20-91\uf20-086.cnf
# Processing uf20-91\uf20-0860.cnf
# Processing uf20-91\uf20-0861.cnf
# Processing uf20-91\uf20-0862.cnf
# Processing uf20-91\uf20-0863.cnf
# Processing uf20-91\uf20-0864.cnf
# Processing uf20-91\uf20-0865.cnf
# Processing uf20-91\uf20-0866.cnf
# Processing uf20-91\uf20-0867.cnf
# Processing uf20-91\uf20-0868.cnf
# Processing uf20-91\uf20-0869.cnf
# Processing uf20-91\uf20-087.cnf
# Processing uf20-91\uf20-0870.cnf
# Processing uf20-91\uf20-0871.cnf
# Processing uf20-91\uf20-0872.cnf
# Processing uf20-91\uf20-0873.cnf
# Processing uf20-91\uf20-0874.cnf
# Processing uf20-91\uf20-0875.cnf
# Processing uf20-91\uf20-0876.cnf
# Processing uf20-91\uf20-0877.cnf
# Processing uf20-91\uf20-0878.cnf
# Processing uf20-91\uf20-0879.cnf
# Processing uf20-91\uf20-088.cnf
# Processing uf20-91\uf20-0880.cnf
# Processing uf20-91\uf20-0881.cnf
# Processing uf20-91\uf20-0882.cnf
# Processing uf20-91\uf20-0883.cnf
# Processing uf20-91\uf20-0884.cnf
# Processing uf20-91\uf20-0885.cnf
# Processing uf20-91\uf20-0886.cnf
# Processing uf20-91\uf20-0887.cnf
# Processing uf20-91\uf20-0888.cnf
# Processing uf20-91\uf20-0889.cnf
# Processing uf20-91\uf20-089.cnf
# Processing uf20-91\uf20-0890.cnf
# Processing uf20-91\uf20-0891.cnf
# Processing uf20-91\uf20-0892.cnf
# Processing uf20-91\uf20-0893.cnf
# Processing uf20-91\uf20-0894.cnf
# Processing uf20-91\uf20-0895.cnf
# Processing uf20-91\uf20-0896.cnf
# Processing uf20-91\uf20-0897.cnf
# Processing uf20-91\uf20-0898.cnf
# Processing uf20-91\uf20-0899.cnf
# Processing uf20-91\uf20-09.cnf
# Processing uf20-91\uf20-090.cnf
# Processing uf20-91\uf20-0900.cnf
# Processing uf20-91\uf20-0901.cnf
# Processing uf20-91\uf20-0902.cnf
# Processing uf20-91\uf20-0903.cnf
# Processing uf20-91\uf20-0904.cnf
# Processing uf20-91\uf20-0905.cnf
# Processing uf20-91\uf20-0906.cnf
# Processing uf20-91\uf20-0907.cnf
# Processing uf20-91\uf20-0908.cnf
# Processing uf20-91\uf20-0909.cnf
# Processing uf20-91\uf20-091.cnf
# Processing uf20-91\uf20-0910.cnf
# Processing uf20-91\uf20-0911.cnf
# Processing uf20-91\uf20-0912.cnf
# Processing uf20-91\uf20-0913.cnf
# Processing uf20-91\uf20-0914.cnf
# Processing uf20-91\uf20-0915.cnf
# Processing uf20-91\uf20-0916.cnf
# Processing uf20-91\uf20-0917.cnf
# Processing uf20-91\uf20-0918.cnf
# Processing uf20-91\uf20-0919.cnf
# Processing uf20-91\uf20-092.cnf
# Processing uf20-91\uf20-0920.cnf
# Processing uf20-91\uf20-0921.cnf
# Processing uf20-91\uf20-0922.cnf
# Processing uf20-91\uf20-0923.cnf
# Processing uf20-91\uf20-0924.cnf
# Processing uf20-91\uf20-0925.cnf
# Processing uf20-91\uf20-0926.cnf
# Processing uf20-91\uf20-0927.cnf
# Processing uf20-91\uf20-0928.cnf
# Processing uf20-91\uf20-0929.cnf
# Processing uf20-91\uf20-093.cnf
# Processing uf20-91\uf20-0930.cnf
# Processing uf20-91\uf20-0931.cnf
# Processing uf20-91\uf20-0932.cnf
# Processing uf20-91\uf20-0933.cnf
# Processing uf20-91\uf20-0934.cnf
# Processing uf20-91\uf20-0935.cnf
# Processing uf20-91\uf20-0936.cnf
# Processing uf20-91\uf20-0937.cnf
# Processing uf20-91\uf20-0938.cnf
# Processing uf20-91\uf20-0939.cnf
# Processing uf20-91\uf20-094.cnf
# Processing uf20-91\uf20-0940.cnf
# Processing uf20-91\uf20-0941.cnf
# Processing uf20-91\uf20-0942.cnf
# Processing uf20-91\uf20-0943.cnf
# Processing uf20-91\uf20-0944.cnf
# Processing uf20-91\uf20-0945.cnf
# Processing uf20-91\uf20-0946.cnf
# Processing uf20-91\uf20-0947.cnf
# Processing uf20-91\uf20-0948.cnf
# Processing uf20-91\uf20-0949.cnf
# Processing uf20-91\uf20-095.cnf
# Processing uf20-91\uf20-0950.cnf
# Processing uf20-91\uf20-0951.cnf
# Processing uf20-91\uf20-0952.cnf
# Processing uf20-91\uf20-0953.cnf
# Processing uf20-91\uf20-0954.cnf
# Processing uf20-91\uf20-0955.cnf
# Processing uf20-91\uf20-0956.cnf
# Processing uf20-91\uf20-0957.cnf
# Processing uf20-91\uf20-0958.cnf
# Processing uf20-91\uf20-0959.cnf
# Processing uf20-91\uf20-096.cnf
# Processing uf20-91\uf20-0960.cnf
# Processing uf20-91\uf20-0961.cnf
# Processing uf20-91\uf20-0962.cnf
# Processing uf20-91\uf20-0963.cnf
# Processing uf20-91\uf20-0964.cnf
# Processing uf20-91\uf20-0965.cnf
# Processing uf20-91\uf20-0966.cnf
# Processing uf20-91\uf20-0967.cnf
# Processing uf20-91\uf20-0968.cnf
# Processing uf20-91\uf20-0969.cnf
# Processing uf20-91\uf20-097.cnf
# Processing uf20-91\uf20-0970.cnf
# Processing uf20-91\uf20-0971.cnf
# Processing uf20-91\uf20-0972.cnf
# Processing uf20-91\uf20-0973.cnf
# Processing uf20-91\uf20-0974.cnf
# Processing uf20-91\uf20-0975.cnf
# Processing uf20-91\uf20-0976.cnf
# Processing uf20-91\uf20-0977.cnf
# Processing uf20-91\uf20-0978.cnf
# Processing uf20-91\uf20-0979.cnf
# Processing uf20-91\uf20-098.cnf
# Processing uf20-91\uf20-0980.cnf
# Processing uf20-91\uf20-0981.cnf
# Processing uf20-91\uf20-0982.cnf
# Processing uf20-91\uf20-0983.cnf
# Processing uf20-91\uf20-0984.cnf
# Processing uf20-91\uf20-0985.cnf
# Processing uf20-91\uf20-0986.cnf
# Processing uf20-91\uf20-0987.cnf
# Processing uf20-91\uf20-0988.cnf
# Processing uf20-91\uf20-0989.cnf
# Processing uf20-91\uf20-099.cnf
# Processing uf20-91\uf20-0990.cnf
# Processing uf20-91\uf20-0991.cnf
# Processing uf20-91\uf20-0992.cnf
# Processing uf20-91\uf20-0993.cnf
# Processing uf20-91\uf20-0994.cnf
# Processing uf20-91\uf20-0995.cnf
# Processing uf20-91\uf20-0996.cnf
# Processing uf20-91\uf20-0997.cnf
# Processing uf20-91\uf20-0998.cnf
# Processing uf20-91\uf20-0999.cnf
